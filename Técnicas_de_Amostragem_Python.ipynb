# %% [markdown]
# <a href="https://colab.research.google.com/github/vickdurazzo/estatistica/blob/main/T%C3%A9cnicas_de_Amostragem_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Técnicas de Amostragem, temos 3 principais :
#
# - **Técnica de amostragem aleatória simples** :
#     - Técnica de amostragem em que todos os indivíduos de uma população têm a mesma chance de serem selecionados para a amostra.
# - **Amostragem Sistemática :**
#     - É como a amostragem aleatória, contudo há um fator matemático de seleção que a diferencia.
#     - Os elementos são divididos em grupos numericamente iguais, então é definido um “ponto de partida”, com intuito de estabelecer um número que se repetirá
#
#         <aside>
#         💡 Por exemplo, em uma pesquisa realizada em um bairro, podemos dividir <b>500 moradias</b> em <b>50 grupos</b>, para obter uma amostragem com 50 residências ,dessa maneira, <b>a cada 10 domicílios 1 pesquisa</b> será realizada.
#
#         Dentro desse grupo um “<b>ponto de partida</b>”, ou seja, um número, deve ser selecionado. Assim, se decidirmos que o **4° domicílio** de um grupo será o selecionado, vamos obter uma sequência(**4, 14, 24, 34… até 494**) determinada de residências para a amostragem.
#
#         </aside>
#
#
# - **Amostragem Estratificada :**
#     - Técnica realizada em duas etapas :
#         1. Dividir a população em grupos distintos
#         2. Escolha de uma forma aleatória ou não de eleger os indivíduos do grupo

# %% [markdown]
# #Amostragem aleatória Simples

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/covid19.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50982 entries, 0 to 50981
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   case_id             0 non-null      float64
#  1   provincial_case_id  50982 non-null  int64
#  2   age                 50982 non-null  object
#  3   sex                 50982 non-null  object
#  4   health_region       50982 non-null  object
#  5   province            50982 non-null  object
#  6   country             50982 non-null  object
#  7   date_report         50982 non-null  object
#  8   report_week         50982 non-null  object
#  9   has_travel_history  1150 non-null   object
#  10  locally_acquired    574 non-null    object
#  11  case_source         50982 non-null  object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 4.7+ MB

# %%
df.head()
# Out:
#    case_id  provincial_case_id    age     sex      health_region province  \
# 0      NaN                   1  50-59    Male            Toronto  Ontario
# 1      NaN                   2  50-59  Female            Toronto  Ontario
# 2      NaN                   1  40-49    Male  Vancouver Coastal       BC
# 3      NaN                   3  20-29  Female   Middlesex-London  Ontario
# 4      NaN                   2  50-59  Female  Vancouver Coastal       BC
#
#   country date_report report_week has_travel_history locally_acquired  \
# 0  Canada  2020-01-25  2020-01-19                  t              NaN
# 1  Canada  2020-01-27  2020-01-26                  t              NaN
# 2  Canada  2020-01-28  2020-01-26                  t              NaN
# 3  Canada  2020-01-31  2020-01-26                  t              NaN
# 4  Canada  2020-02-04  2020-02-02                  f    Close Contact
#
#                                          case_source
# ...

# %% [markdown]
# Criando uma amostra com apenas 10 registros a partir do conjunto de dados

# %%
df_sample = df.sample(n=1000)

# %%
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 36899 to 50784
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   case_id             0 non-null      float64
#  1   provincial_case_id  1000 non-null   int64
#  2   age                 1000 non-null   object
#  3   sex                 1000 non-null   object
#  4   health_region       1000 non-null   object
#  5   province            1000 non-null   object
#  6   country             1000 non-null   object
#  7   date_report         1000 non-null   object
#  8   report_week         1000 non-null   object
#  9   has_travel_history  22 non-null     object
#  10  locally_acquired    9 non-null      object
#  11  case_source         1000 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 101.6+ KB

# %% [markdown]
# Especificando o tamanho da amostra através do percentual

# %%
df_sample =  df.sample(frac=0.10)

# %%
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5098 entries, 3390 to 38558
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   case_id             0 non-null      float64
#  1   provincial_case_id  5098 non-null   int64
#  2   age                 5098 non-null   object
#  3   sex                 5098 non-null   object
#  4   health_region       5098 non-null   object
#  5   province            5098 non-null   object
#  6   country             5098 non-null   object
#  7   date_report         5098 non-null   object
#  8   report_week         5098 non-null   object
#  9   has_travel_history  123 non-null    object
#  10  locally_acquired    63 non-null     object
#  11  case_source         5098 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 517.8+ KB

# %% [markdown]
# # Amostragem Aleatória Estratificada

# %% [markdown]
# importando o método train_test_split para fazer a amostragem (muito usado no ML para definir pequenas amostras de treino para o algoritmo gerar o modelo)

# %%
from sklearn.model_selection import train_test_split

# %%
df['province'].value_counts()
# Out:
# Quebec           25757
# Ontario          16337
# Alberta           4850
# BC                2053
# Nova Scotia        915
# Saskatchewan       366
# Manitoba           272
# NL                 258
# New Brunswick      118
# PEI                 27
# Repatriated         13
# Yukon               11
# NWT                  5
# Name: province, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop('province',axis=1),
                                                    df['province'],
                                                    stratify = df['province'],
                                                    test_size = 0.20
                                                    )

# %% [markdown]
# Verificando a forma dos dados

# %%
y_test.shape
# Out:
# (10197,)

# %%
y_test.value_counts()
# Out:
# Quebec           5152
# Ontario          3267
# Alberta           970
# BC                411
# Nova Scotia       183
# Saskatchewan       73
# Manitoba           54
# NL                 52
# New Brunswick      24
# PEI                 5
# Repatriated         3
# Yukon               2
# NWT                 1
# Name: province, dtype: int64

# %% [markdown]
# # Amostragem Sistemática

# %%
import numpy as np

# %%
semente = np.random.choice(10,1)

# %%
semente
# Out:
# array([4])

# %% [markdown]
# Gerando índices a partir da semente

# %%
indices = np.arange(0,100,semente)

# %%
indices
# Out:
# array([ 0,  4,  8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64,
#        68, 72, 76, 80, 84, 88, 92, 96])

# %% [markdown]
# Gerando amostra a partir dos índices

# %%
amostra = df.loc[indices,:]

# %% [markdown]
# Verificando dados da amostra

# %%
amostra
# Out:
#     case_id  provincial_case_id    age     sex      health_region province  \
# 0       NaN                   1  50-59    Male            Toronto  Ontario
# 4       NaN                   2  50-59  Female  Vancouver Coastal       BC
# 8       NaN                   6  30-39  Female             Fraser       BC
# 12      NaN                   6  60-69    Male            Toronto  Ontario
# 16      NaN                   9  30-39  Female               York  Ontario
# 20      NaN                  12  50-59    Male               York  Ontario
# 24      NaN                  16  60-69  Female               York  Ontario
# 28      NaN                  20  50-59    Male            Toronto  Ontario
# 32      NaN                  12  30-39  Female  Vancouver Coastal       BC
# 36      NaN                  22  60-69    Male            Toronto  Ontario
# 40      NaN                  16  50-59  Female  Vancouver Coastal       BC
# ...

# %%
amostra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 0 to 96
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   case_id             0 non-null      float64
#  1   provincial_case_id  25 non-null     int64
#  2   age                 25 non-null     object
#  3   sex                 25 non-null     object
#  4   health_region       25 non-null     object
#  5   province            25 non-null     object
#  6   country             25 non-null     object
#  7   date_report         25 non-null     object
#  8   report_week         25 non-null     object
#  9   has_travel_history  25 non-null     object
#  10  locally_acquired    5 non-null      object
#  11  case_source         25 non-null     object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 2.5+ KB
